# %% [markdown]
# ### TruncatedSVD & Text Mining

# %%
tweets=['cats say meow', 'dogs say woof', 'dogs chase cats']
# Import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TfidfVectorizer: tfidf
tfidf = TfidfVectorizer() 

# Apply fit_transform to document: csr_mat
csr_mat = tfidf.fit_transform(tweets)

# Print result of toarray() method
print(csr_mat.toarray())

# Get the words: words
words = tfidf.get_feature_names()

# Print words
print(words)
# Out:
# [[0.51785612 0.         0.         0.68091856 0.51785612 0.        ]
#  [0.         0.         0.51785612 0.         0.51785612 0.68091856]
#  [0.51785612 0.68091856 0.51785612 0.         0.         0.        ]]
# ['cats', 'chase', 'dogs', 'meow', 'say', 'woof']

# %%
# Perform the necessary imports
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline

# Create a TruncatedSVD instance: svd
svd = TruncatedSVD(n_components=50)

# Create a KMeans instance: kmeans
kmeans = KMeans(n_clusters=6)

# Create a pipeline: pipeline
pipeline = make_pipeline(svd, kmeans)

# %%
import pandas as pd

document=pd.read_csv('nlp.data.csv')

#text=pd.read_csv("wikipedia_utf8_filtered_20pageviews.csv", nrows=100000)

# %%
document.iloc[:,2]
# Out:
# 0         The Death of Bunny Munro  The Death of Bunny ...
# 1         Management of prostate cancer  Treatment for ...
# 2         Cheetah reintroduction in India  Reintroducti...
# 3         Langtang National Park  The Langtang National...
# 4         Shivapuri Nagarjun National Park  Shivapuri N...
# 5         Bob Benmosche  Robert H. "Bob" Benmosche (bor...
# 6         Lady Apache  Sandra González Calderón (born J...
# 7         Do You Want the Truth or Something Beautiful?...
# 8         Philippine Fault System  The Philippine Fault...
# 9         Abandoned pets  Abandoned pets are both exoti...
# 10        Chadalavada Umesh Chandra  Chadalavada Umesh ...
# 11        Texts From Last Night  Texts From Last Night ...
# 12        María de Villota  María de Villota Comba (bor...
# 13        Tom Maynard  Thomas Lloyd "Tom" Maynard (25 M...
# 14        Jikki  Pillavalu Gajapathi Krishnaveni was a ...
# 15        Tara Stiles  Tara Leann Stiles (born May 6, 1...
# 16        Isaac Redman  Isaac Redman (born November 10,...
# 17        Doctor Steel  Doctor Steel (full name, Doctor...
# 18        Janice Man  Janice Man (born December 29, 198...
# 19        Toi gold mine  The Toi gold mine (Japanese: 土...
# 20        Production of Watchmen  Watchmen is a 2009 fi...
# 21        Český Krumlov  Český Krumlov (; or "Böhmisch ...
# 22        National Open University  National Open Unive...
# 23        Irish Mercantile Marine during World War II  ...
# 24        Sticky-shed syndrome  Sticky-shed syndrome is...
# 25        Return-oriented programming  Return-oriented ...
# 26        Damon Wilson  Damon Wilson is an American for...
# 27        Coronation of Queen Elizabeth II  The coronat...
# 28        Manchester Mark 1  The Manchester Mark 1 was ...
# 29        Tryton  Tryton is a three-tier high-level gen...
#                                ...
# 99970     Take the Lead  Take the Lead is a 2006 musica...
# 99971     Jan Mohammad Khan  Jan Mohammad Khan (died Ju...
# 99972     Simcha  Simcha ( ; , ) is a Hebrew word with ...
# 99973     Microsoft Press  Microsoft Press is the publi...
# 99974     Steve Lavin  Steve Lavin (born September 4, 1...
# 99975     Soviet cuisine  Soviet cuisine, the common cu...
# 99976     Street Racing Syndicate  Street Racing Syndic...
# 99977     Pepper Dennis  Pepper Dennis is a comedy-dram...
# 99978     Charles Nicoletti  Charles "Chuckie" Nicolett...
# 99979     Naked party  A naked or nude party is a party...
# 99980     Economy of Kolkata  Kolkata is the main busin...
# 99981     Geography of Kolkata  Kolkata is located in t...
# 99982     Aditi Gowitrikar  Aditi Gowitrikar (born May ...
# 99983     Danny Care  Daniel Care (born 2 January 1987)...
# 99984     Barry Robson  Barry Gordon George Robson (bor...
# 99985     Jang Woo-hyuk  Jang Woo Hyuk (born May 8, 197...
# 99986     Euryhaline  Euryhaline organisms are able to ...
# 99987     British big cats  British big cats, also refe...
# 99988     Mrs. World  Mrs. World is an international be...
# 99989     Interference lithography  Interference lithog...
# 99990     Underboss  __NOTOC__ Underboss (also capo bas...
# 99991     Waterborne diseases  Waterborne diseases are ...
# 99992     Jason Bradbury  Jason Bradbury is an English ...
# 99993     Marcelinho Paraíba  Marcelo dos Santos (born ...
# 99994     Renewable heat  Renewable heat is an applicat...
# 99995     Pro aris et focis  Pro Aris et Focis is a Lat...
# 99996     Wayne Hemingway  Wayne Andrew Hemingway, MBE ...
# 99997     Latvian Academy of Sciences  The Academy of S...
# 99998     HiRISE  "For the Apple accessory see Twelve S...
# 99999     Hikoi  Hikoi is a term of the Maori language ...
# Name:  Research Design and Standards Organization  The Research Design and Standards Organisation (RDSO) is an ISO 9001 research and development organisation under the Ministry of Railways of India, which functions as a technical adviser and consultant to the Railway Board, the Zonal Railways, the Railway Production Units, RITES and IRCON International in respect of design and standardisation of railway equipment and problems related to railway construction, operation and maintenance. History. To enforce standardisation and co-ordination between various railway systems in British India, the Indian Railway Conference Association (IRCA) was set up in 1903. It was followed by the establishment of the Central Standards Office (CSO) in 1930, for preparation of designs, standards and specifications. However, till independence in 1947, most of the designs and manufacture of railway equipments was entrusted to foreign consultants. After independence, a new organisation called Railway Testing and Research Centre (RTRC) was set up in 1952 at Lucknow, for undertaking intensive investigation of railway problems, providing basic criteria and new concepts for design purposes, for testing prototypes and generally assisting in finding solutions for specific problems. In 1957, the Central Standards Office (CSO) and the Railway Testing and Research Centre (RTRC) were integrated into a single unit named Research Designs and Standards Organisation (RDSO) under the Ministry of Railways with its headquarters at Manaknagar, Lucknow. The status of RDSO was changed from an "Attached Office" to a "Zonal Railway" on April 1, 2003, to give it greater flexibility and a boost to the research and development activities. Organisation. The RDSO is headed by a Director General who ranks with a General Manager of a Zonal Railway. The Director General is assisted by an Additional Director General and 23 Sr. Executive Directors and Executive Directors, who are in charge of the 27 directorates: Bridges and Structures, the Centre for Advanced Maintenance Techlogy (AMTECH), Carriage, Geotechnical Engineering, Testing, Track Design, Medical, EMU & Power Supply, Engine Development, Finance & Accounts, Telecommunication, Quality Assurance, Personnel, Works, Psycho-Technical, Research, Signal, Wagon Design, Electric Locomotive, Stores, Track Machines & Monitoring, Traction Installation, Energy Management, Traffic, Metallurgical & Chemical, Motive Power and Library & Publications. All the directorates except Defence Research are located in Lucknow. Projects. Development of a new crashworthy design of  4500 HP WDG4 locomotive incorporating new  technology to improve dynamic braking and attain  significant fuel savings. Development of Drivers’ Vigilance Telemetric Control  System which directly measures and analyses variations  in biometric parameters to determine the state of alertness  of the driver. Development of Train Collision Avoidance System(TCAS). Development of Computer Aided Drivers Aptitude test  equipment for screening high speed train drivers for  Rajdhani/Shatabdi Express trains to evaluate their reaction  time, form perception, vigilance and speed anticipation. Assessment of residual fatigue life of critical railway  components like rail, rail weld, wheels, cylinder head, OHE  mast, catenary wire, contact wire, wagon components, low  components, etc. to formulate remedial actions. Modification of specification of Electric Lifting Barrier to improve its strength and reliability Design and development of modern fault tolerant, fail-safe, maintainer friendly Electronic Interlocking system Development of 4500 HP Hotel Load Locomotive to provide clean and noise free power supply to coaches from locomotive to eliminate the existing generator car of Garib Rath express trains. Field trials conducted for electric locomotive hauling Rajdhani/Shatabdi express trains with Head On Generation (HOG) system to provide clean and noise free power supply to end on coaches. De ...

# %%
import pandas as pd                                             
from sklearn.feature_extraction.text import TfidfVectorizer

#Feature Transformation

tfidf_vectorizer = TfidfVectorizer(max_features= 1000000)
tfidf = tfidf_vectorizer.fit_transform(document.iloc[:,2])

# %%
titles=['HTTP 404',
 'Alexa Internet',
 'Internet Explorer',
 'HTTP cookie',
 'Google Search',
 'Tumblr',
 'Hypertext Transfer Protocol',
 'Social search',
 'Firefox',
 'LinkedIn',
 'Global warming',
 'Nationally Appropriate Mitigation Action',
 'Nigel Lawson',
 'Connie Hedegaard',
 'Climate change',
 'Kyoto Protocol',
 '350.org',
 'Greenhouse gas emissions by the United States',
 '2010 United Nations Climate Change Conference',
 '2007 United Nations Climate Change Conference',
 'Angelina Jolie',
 'Michael Fassbender',
 'Denzel Washington',
 'Catherine Zeta-Jones',
 'Jessica Biel',
 'Russell Crowe',
 'Mila Kunis',
 'Dakota Fanning',
 'Anne Hathaway',
 'Jennifer Aniston',
 'France national football team',
 'Cristiano Ronaldo',
 'Arsenal F.C.',
 'Radamel Falcao',
 'Zlatan Ibrahimović',
 'Colombia national football team',
 '2014 FIFA World Cup qualification',
 'Football',
 'Neymar',
 'Franck Ribéry',
 'Tonsillitis',
 'Hepatitis B',
 'Doxycycline',
 'Leukemia',
 'Gout',
 'Hepatitis C',
 'Prednisone',
 'Fever',
 'Gabapentin',
 'Lymphoma',
 'Chad Kroeger',
 'Nate Ruess',
 'The Wanted',
 'Stevie Nicks',
 'Arctic Monkeys',
 'Black Sabbath',
 'Skrillex',
 'Red Hot Chili Peppers',
 'Sepsis',
 'Adam Levine']

# %%
# Perform the necessary imports
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline

# Create a TruncatedSVD instance: svd
svd = TruncatedSVD(n_components=50)

# Create a KMeans instance: kmeans
kmeans = KMeans(n_clusters=6)

# Create a pipeline: pipeline
pipeline = make_pipeline(svd, kmeans)


# Import pandas
import pandas as pd

# Fit the pipeline to articles
pipeline.fit(tfidf)

# Calculate the cluster labels: labels
labels = pipeline.predict(tfidf)
print(len(labels))

# Create a DataFrame aligning labels and titles: df
df = pd.DataFrame({'label': labels, 'article': titles})

# Display df sorted by cluster label
print(df.sort_values('label'))
# Out:
# 60
#                                           article  label
# 0                                        HTTP 404      0
# 30                  France national football team      0
# 32                                   Arsenal F.C.      0
# 33                                 Radamel Falcao      0
# 35                Colombia national football team      0
# 36              2014 FIFA World Cup qualification      0
# 37                                       Football      0
# 38                                         Neymar      0
# 39                                  Franck Ribéry      0
# 40                                    Tonsillitis      0
# 41                                    Hepatitis B      0
# 42                                    Doxycycline      0
# 43                                       Leukemia      0
# 45                                    Hepatitis C      0
# 46                                     Prednisone      0
# 47                                          Fever      0
# 48                                     Gabapentin      0
# 49                                       Lymphoma      0
# 51                                     Nate Ruess      0
# 52                                     The Wanted      0
# 53                                   Stevie Nicks      0
# 54                                 Arctic Monkeys      0
# 55                                  Black Sabbath      0
# 57                          Red Hot Chili Peppers      0
# 28                                  Anne Hathaway      0
# 27                                 Dakota Fanning      0
# 29                               Jennifer Aniston      0
# 25                                  Russell Crowe      0
# 1                                  Alexa Internet      0
# 2                               Internet Explorer      0
# 5                                          Tumblr      0
# 6                     Hypertext Transfer Protocol      0
# 8                                         Firefox      0
# 10                                 Global warming      0
# 11       Nationally Appropriate Mitigation Action      0
# 26                                     Mila Kunis      0
# 13                               Connie Hedegaard      0
# 15                                 Kyoto Protocol      0
# 16                                        350.org      0
# 59                                    Adam Levine      0
# 24                                   Jessica Biel      0
# 19  2007 United Nations Climate Change Conference      0
# 20                                 Angelina Jolie      0
# 23                           Catherine Zeta-Jones      0
# 21                             Michael Fassbender      0
# 22                              Denzel Washington      0
# 17  Greenhouse gas emissions by the United States      0
# 31                              Cristiano Ronaldo      1
# 18  2010 United Nations Climate Change Conference      2
# 56                                       Skrillex      2
# 12                                   Nigel Lawson      2
# 14                                 Climate change      2
# 50                                   Chad Kroeger      2
# 34                             Zlatan Ibrahimović      3
# 58                                         Sepsis      3
# 44                                           Gout      3
# 7                                   Social search      3
# 4                                   Google Search      4
# 3                                     HTTP cookie      4
# 9                                        LinkedIn      5

# %%
# Perform the necessary imports
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline

# Create a TruncatedSVD instance: svd
svd = TruncatedSVD(n_components=50)

# Create a KMeans instance: kmeans
kmeans = KMeans(n_clusters=6)

# Create a pipeline: pipeline
pipeline = make_pipeline(svd, kmeans)


# Fit the pipeline to articles
pipeline.fit(tfidf)

# Calculate the cluster labels: labels
labels = pipeline.predict(tfidf)
print(len(labels))
# Out:
# 100000

# %%
a_label=labels[0:60]

# %%
# Create a DataFrame aligning labels and titles: df
df = pd.DataFrame({'label': a_label, 'article': titles})

# Display df sorted by cluster label
print(df.sort_values('label'))
# Out:
#                                           article  label
# 56                                       Skrillex      0
# 50                                   Chad Kroeger      0
# 18  2010 United Nations Climate Change Conference      0
# 15                                 Kyoto Protocol      0
# 42                                    Doxycycline      0
# 14                                 Climate change      0
# 12                                   Nigel Lawson      0
# 59                                    Adam Levine      1
# 27                                 Dakota Fanning      1
# 20                                 Angelina Jolie      1
# 28                                  Anne Hathaway      1
# 35                Colombia national football team      1
# 23                           Catherine Zeta-Jones      1
# 39                                  Franck Ribéry      1
# 47                                          Fever      1
# 40                                    Tonsillitis      2
# 32                                   Arsenal F.C.      2
# 30                  France national football team      2
# 48                                     Gabapentin      2
# 49                                       Lymphoma      2
# 53                                   Stevie Nicks      2
# 57                          Red Hot Chili Peppers      2
# 25                                  Russell Crowe      2
# 37                                       Football      2
# 0                                        HTTP 404      2
# 8                                         Firefox      2
# 1                                  Alexa Internet      2
# 2                               Internet Explorer      2
# 3                                     HTTP cookie      2
# 4                                   Google Search      2
# 24                                   Jessica Biel      2
# 11       Nationally Appropriate Mitigation Action      2
# 29                               Jennifer Aniston      2
# 21                             Michael Fassbender      2
# 19  2007 United Nations Climate Change Conference      2
# 17  Greenhouse gas emissions by the United States      2
# 33                                 Radamel Falcao      3
# 52                                     The Wanted      3
# 51                                     Nate Ruess      3
# 5                                          Tumblr      3
# 6                     Hypertext Transfer Protocol      3
# 45                                    Hepatitis C      3
# 43                                       Leukemia      3
# 22                              Denzel Washington      3
# 9                                        LinkedIn      3
# 31                              Cristiano Ronaldo      3
# 44                                           Gout      4
# 7                                   Social search      4
# 58                                         Sepsis      4
# 36              2014 FIFA World Cup qualification      4
# 34                             Zlatan Ibrahimović      4
# 16                                        350.org      5
# 10                                 Global warming      5
# 38                                         Neymar      5
# 13                               Connie Hedegaard      5
# 54                                 Arctic Monkeys      5
# 55                                  Black Sabbath      5
# 26                                     Mila Kunis      5
# 41                                    Hepatitis B      5
# 46                                     Prednisone      5

# %%
                                            article  label
14                                 Climate change      0
17  Greenhouse gas emissions by the United States      0
16                                        350.org      0
15                                 Kyoto Protocol      0
13                               Connie Hedegaard      0
12                                   Nigel Lawson      0
11       Nationally Appropriate Mitigation Action      0
10                                 Global warming      0
18  2010 United Nations Climate Change Conference      0
19  2007 United Nations Climate Change Conference      0
47                                          Fever      1
46                                     Prednisone      1
45                                    Hepatitis C      1
44                                           Gout      1
40                                    Tonsillitis      1
43                                       Leukemia      1
42                                    Doxycycline      1
41                                    Hepatitis B      1
48                                     Gabapentin      1
49                                       Lymphoma      1
59                                    Adam Levine      2
51                                     Nate Ruess      2
52                                     The Wanted      2
53                                   Stevie Nicks      2
54                                 Arctic Monkeys      2
55                                  Black Sabbath      2
56                                       Skrillex      2
57                          Red Hot Chili Peppers      2
50                                   Chad Kroeger      2
58                                         Sepsis      2
0                                        HTTP 404      3
1                                  Alexa Internet      3
2                               Internet Explorer      3
3                                     HTTP cookie      3
4                                   Google Search      3
5                                          Tumblr      3
6                     Hypertext Transfer Protocol      3
7                                   Social search      3
8                                         Firefox      3
9                                        LinkedIn      3
23                           Catherine Zeta-Jones      4
20                                 Angelina Jolie      4
21                             Michael Fassbender      4
22                              Denzel Washington      4
29                               Jennifer Aniston      4
25                                  Russell Crowe      4
26                                     Mila Kunis      4
27                                 Dakota Fanning      4
28                                  Anne Hathaway      4
24                                   Jessica Biel      4
30                  France national football team      5
39                                  Franck Ribéry      5
38                                         Neymar      5
37                                       Football      5
36              2014 FIFA World Cup qualification      5
35                Colombia national football team      5
34                             Zlatan Ibrahimović      5
33                                 Radamel Falcao      5
32                                   Arsenal F.C.      5
31                              Cristiano Ronaldo      5
